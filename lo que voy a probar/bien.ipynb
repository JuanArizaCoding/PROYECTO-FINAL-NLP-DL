# %%
# INSTALL 

# !pip install -q -U chromadb sentence-transformers transformers accelerate bitsandbytes
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 41.3 MB/s eta 0:00:0000:0100:01m
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.3/571.3 kB 52.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 143.2 MB/s eta 0:00:0000:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 43.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 32.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 102.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 90.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.1/72.1 kB 9.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.2/180.2 kB 24.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 9.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.6/231.6 kB 28.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 9.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 7.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-exporter-otlp-proto-common==1.38.0, but you have opentelemetry-exporter-otlp-proto-common 1.41.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-proto==1.38.0, but you have opentelemetry-proto 1.41.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-sdk~=1.38.0, but you have opentelemetry-sdk 1.41.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-api<1.39.0,>=1.36.0, but you have opentelemetry-api 1.41.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-sdk<1.39.0,>=1.36.0, but you have opentelemetry-sdk 1.41.1 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-sdk<1.39.0,>=1.35.0, but you have opentelemetry-sdk 1.41.1 which is incompatible.

# %%
# IMPORTS

import re
import shutil
import torch
from pathlib import Path

import chromadb
from sentence_transformers import SentenceTransformer
from transformers import AutoProcessor, AutoModelForCausalLM, BitsAndBytesConfig, GenerationConfig
from huggingface_hub import login

# %%
# LOGIN HUGGING FACE Y DRIVE
login("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")

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# =========================
# CONFIG
# =========================

DRIVE_DB_LIBRO  = Path("/content/drive/MyDrive/NLP_PRACTICA/Persist/libro_largo_qwen")
DRIVE_DB_RESUMEN = Path("/content/drive/MyDrive/NLP_PRACTICA/Persist/chroma_db_resumenes_qwen")

LOCAL_DB_LIBRO  = Path("/content/chroma_got_rag_libro_largo_qwen")
LOCAL_DB_RESUMEN = Path("/content/chroma_got_rag_resumenes_qwen")

COLLECTION_LIBRO = "libro"
COLLECTION_RESUMEN = "resumenes_got"

EMBED_MODEL_NAME = "Qwen/Qwen3-Embedding-8B"
LLM_MODEL_NAME   = "google/gemma-4-31B-it"

TOP_K = 5
MAX_NEW_TOKENS = 256

# %%
# =========================
# 1. COPIAR CHROMA DE DRIVE
# =========================

def load_chroma_from_drive() -> tuple[chromadb.Collection, chromadb.Collection]:
    if LOCAL_DB_LIBRO.exists():
        shutil.rmtree(LOCAL_DB_LIBRO)

    print("Copiando Chroma del Libro de Drive a /content...")
    shutil.copytree(DRIVE_DB_LIBRO, LOCAL_DB_LIBRO)

    if LOCAL_DB_RESUMEN.exists():
        shutil.rmtree(LOCAL_DB_RESUMEN)

    print("Copiando Chroma de Resúmenes de Drive a /content...")
    shutil.copytree(DRIVE_DB_RESUMEN, LOCAL_DB_RESUMEN)

    client_libro = chromadb.PersistentClient(path=str(LOCAL_DB_LIBRO))
    col_libro = client_libro.get_collection(COLLECTION_LIBRO)

    client_resumen = chromadb.PersistentClient(path=str(LOCAL_DB_RESUMEN))
    col_resumen = client_resumen.get_collection(COLLECTION_RESUMEN)

    print(f"  → Colección Libro cargada: {col_libro.count()} chunks")
    print(f"  → Colección Resúmenes cargada: {col_resumen.count()} chunks")

    return col_libro, col_resumen

# %%
# =========================
# 2. CARGAR MODELOS
# =========================

def load_embedder() -> SentenceTransformer:
    print("Cargando embedder Qwen3-Embedding-8B...")
    return SentenceTransformer(
        EMBED_MODEL_NAME,
        model_kwargs={"torch_dtype": torch.bfloat16}
    )


def load_llm():
    print("Cargando LLM Gemma 4 31B IT en 4-bit...")

    processor = AutoProcessor.from_pretrained(LLM_MODEL_NAME)

    quant_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_use_double_quant=True,
        bnb_4bit_compute_dtype=torch.bfloat16
    )

    model = AutoModelForCausalLM.from_pretrained(
        LLM_MODEL_NAME,
        device_map="auto",
        torch_dtype=torch.bfloat16,
        quantization_config=quant_config,
        low_cpu_mem_usage=True
    )

    model.eval()

    model.generation_config = GenerationConfig(
        max_new_tokens=MAX_NEW_TOKENS,
        do_sample=False,
        temperature=None,
        top_p=None,
        top_k=None,
        repetition_penalty=1.08,
        pad_token_id=processor.tokenizer.eos_token_id,
        eos_token_id=processor.tokenizer.eos_token_id
    )

    return processor, model

# %%
# =========================
# 3. RECUPERACIÓN DOBLE
# =========================

def retrieve_from_col(col: chromadb.Collection, emb: list, top_k: int) -> list[dict]:
    try:
        results = col.query(
            query_embeddings=[emb],
            n_results=top_k,
            include=["documents", "metadatas", "distances"]
        )

        chunks = []

        for doc, meta, dist in zip(
            results["documents"][0],
            results["metadatas"][0],
            results["distances"][0]
        ):
            chunks.append({
                "text": doc,
                "metadata": meta,
                "score": round(1 - dist, 4)
            })

        return chunks

    except Exception as e:
        print(f"Aviso: no se pudo recuperar de una colección: {e}")
        return []


def retrieve(
    col_libro: chromadb.Collection,
    col_resumen: chromadb.Collection,
    embedder: SentenceTransformer,
    query: str,
    top_k: int = TOP_K
) -> list[dict]:

    query_prefixed = "Represent this sentence for searching relevant passages: " + query

    emb = embedder.encode(
        query_prefixed,
        normalize_embeddings=True
    ).tolist()

    chunks_libro = retrieve_from_col(col_libro, emb, top_k)
    chunks_resumen = retrieve_from_col(col_resumen, emb, top_k)

    for c in chunks_libro:
        c["source"] = "Libro"

    for c in chunks_resumen:
        c["source"] = "Web Scraper"

    all_chunks = chunks_libro + chunks_resumen
    all_chunks.sort(key=lambda x: x["score"], reverse=True)

    return all_chunks[:top_k]

# %%
# =========================
# 4. CONSTRUCCIÓN DEL PROMPT
# =========================

def build_rag_prompt(query: str, chunks: list[dict]) -> tuple[str, str]:
    context_parts = []

    for i, chunk in enumerate(chunks, 1):
        meta = chunk["metadata"]
        source = chunk.get("source", "N/A")

        chapter = meta.get("chapter_title") or meta.get("chapter", "N/A")
        pov = meta.get("pov", "N/A")

        context_parts.append(
            f"[Fragmento {i} — Fuente: {source}, Capítulo: {chapter}, "
            f"POV: {pov}, Similitud: {chunk['score']}]\n"
            f"{chunk['text']}"
        )

    context = "\n\n---\n\n".join(context_parts)

    system = (
        "Eres un asistente experto en la novela Juego de Tronos. "
        "Responde en español usando ÚNICAMENTE la información de los fragmentos proporcionados. "
        "Si la respuesta no está en los fragmentos, dilo explícitamente. "
        "No inventes información. "
        "Responde de manera clara, breve y directa."
    )

    user = f"""Fragmentos recuperados del libro y de resúmenes web:

{context}

---

Pregunta: {query}

Responde basándote exclusivamente en los fragmentos anteriores."""

    return system, user

# %%
# =========================
# 5. GENERACIÓN CON GEMMA 4
# =========================

def generate_answer(processor, model, query: str, chunks: list[dict]) -> str:
    system, user = build_rag_prompt(query, chunks)

    prompt = f"""<start_of_turn>user
{system}

{user}
<end_of_turn>
<start_of_turn>model
"""

    inputs = processor.tokenizer(
        prompt,
        return_tensors="pt",
        truncation=True,
        max_length=12000
    ).to(model.device)

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=MAX_NEW_TOKENS,
            do_sample=False,
            repetition_penalty=1.08,
            eos_token_id=processor.tokenizer.eos_token_id,
            pad_token_id=processor.tokenizer.eos_token_id
        )

    generated_ids = outputs[0][inputs["input_ids"].shape[1]:]

    answer = processor.tokenizer.decode(
        generated_ids,
        skip_special_tokens=True
    ).strip()

    return answer

# %%
# =========================
# 6. EVALUACIÓN SIMPLE DE FIDELIDAD
# =========================

def simple_faithfulness_check(answer: str, chunks: list[dict], min_overlap: float = 0.35) -> dict:
    """
    Approximate faithfulness check.

    It splits the generated answer into sentences and checks whether the relevant
    words from each sentence appear in the retrieved context.
    """

    context = " ".join(chunk["text"] for chunk in chunks).lower()

    sentences = re.split(r"[.!?]\s+", answer)

    supported = []
    unsupported = []

    for sent in sentences:
        sent_clean = sent.strip()

        if not sent_clean:
            continue

        words = [
            w.lower()
            for w in re.findall(r"\w+", sent_clean)
            if len(w) > 4
        ]

        if not words:
            unsupported.append({
                "sentence": sent_clean,
                "overlap_ratio": 0.0
            })
            continue

        overlap = sum(1 for w in words if w in context)
        ratio = overlap / len(words)

        item = {
            "sentence": sent_clean,
            "overlap_ratio": round(ratio, 3)
        }

        if ratio >= min_overlap:
            supported.append(item)
        else:
            unsupported.append(item)

    total = len(supported) + len(unsupported)

    faithfulness_score = len(supported) / total if total > 0 else 0.0

    return {
        "faithfulness_score": round(faithfulness_score, 3),
        "supported_sentences": supported,
        "unsupported_sentences": unsupported
    }

# %%
# =========================
# 7. IMPRESIÓN DE RESULTADOS
# =========================

def print_chunks(chunks: list[dict]):
    print("\n── Fragmentos recuperados ──────────────────────────────")

    for i, chunk in enumerate(chunks, 1):
        meta = chunk["metadata"]
        source = chunk.get("source", "N/A")

        chapter = meta.get("chapter_title") or meta.get("chapter", "N/A")
        pov = meta.get("pov", "N/A")
        chars = meta.get("characters", "N/A")

        print(
            f"  [{i}] [{source}] {chapter} | "
            f"POV: {pov} | "
            f"Score: {chunk['score']} | "
            f"Personajes: {chars}"
        )

    print("────────────────────────────────────────────────────────\n")


def print_faithfulness(faithfulness: dict):
    print("📊 Evaluación aproximada de fidelidad")
    print(f"Faithfulness score: {faithfulness['faithfulness_score']}")

    if faithfulness["unsupported_sentences"]:
        print("\n⚠️ Frases potencialmente no soportadas por los chunks:")

        for item in faithfulness["unsupported_sentences"]:
            print(f"- {item['sentence']} | overlap={item['overlap_ratio']}")
    else:
        print("\n✅ Todas las frases parecen estar razonablemente soportadas.")

    print()

# %%
# =========================
# 8. ASK
# =========================

def ask(
    query: str,
    col_libro,
    col_resumen,
    embedder,
    processor,
    model,
    show_chunks: bool = True,
    show_faithfulness: bool = True
):
    print(f"\n❓ Pregunta: {query}")

    chunks = retrieve(
        col_libro=col_libro,
        col_resumen=col_resumen,
        embedder=embedder,
        query=query
    )

    if show_chunks:
        print_chunks(chunks)

    answer = generate_answer(
        processor=processor,
        model=model,
        query=query,
        chunks=chunks
    )

    print(f"💬 Respuesta:\n{answer}\n")

    faithfulness = simple_faithfulness_check(answer, chunks)

    if show_faithfulness:
        print_faithfulness(faithfulness)

    return {
        "query": query,
        "chunks": chunks,
        "answer": answer,
        "faithfulness": faithfulness
    }

# %%
# =========================
# MAIN
# =========================

def main():
    col_libro, col_resumen = load_chroma_from_drive()
    embedder = load_embedder()
    processor, model = load_llm()

    print("\n✅ Sistema RAG listo. Escribe 'salir' para terminar.\n")

    while True:
        query = input("❓ Pregunta: ").strip()

        if not query:
            continue

        if query.lower() == "salir":
            break

        ask(
            query=query,
            col_libro=col_libro,
            col_resumen=col_resumen,
            embedder=embedder,
            processor=processor,
            model=model,
            show_chunks=True,
            show_faithfulness=True
        )

# %%
if __name__ == "__main__":
    main()
# Out:
# Copiando Chroma del Libro de Drive a /content...
# Copiando Chroma de Resúmenes de Drive a /content...
#   → Colección Libro cargada: 328 chunks
#   → Colección Resúmenes cargada: 320 chunks
# Cargando embedder Qwen3-Embedding-8B...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:103: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/215 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/729 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/398 [00:00<?, ?it/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/313 [00:00<?, ?B/s]
# Cargando LLM Gemma 4 31B IT en 4-bit...
# processor_config.json: 0.00B [00:00, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/32.2M [00:00<?, ?B/s]
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/1188 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/208 [00:00<?, ?B/s]
# ✅ Sistema RAG listo. Escribe 'salir' para terminar.
#
#
# ❓ Pregunta: ¿Con quién se encuetra Tyrion en la montaña después de salir del Nido de Águilas?
#
# ── Fragmentos recuperados ──────────────────────────────
#   [1] [Libro] TYRION (5) | POV: TYRION | Score: 0.3809 | Personajes: Tyrion, Lysa Arryn, Catelyn Stark, Bronn, Lord Robert, Jaime Lannister, Lord Tywin
#   [2] [Libro] TYRION (6) | POV: TYRION | Score: 0.3435 | Personajes: Tyrion, Bronn, Mord, Jaime, Lady Stark, Lady Arryn
#   [3] [Libro] CATELYN (6) | POV: CATELYN | Score: 0.3434 | Personajes:
#   [4] [Libro] TYRION (3) | POV: TYRION | Score: 0.333 | Personajes: Tyrion, Jon Nieve, Fantasma, Grenn, Pyp, Thorne, Alliser, Halder, Rickon, Bran
#   [5] [Libro] TYRION (5) | POV: TYRION | Score: 0.3046 | Personajes: Tyrion Lannister, Mord, Lady Lysa, el señor del Nido de Águilas
# ────────────────────────────────────────────────────────
#
# 💬 Respuesta:
# thought
# Después de salir del Nido de Águilas, Tyrion se encuentra con **Bronn**. Ambos planean su escape y buscan la forma de llegar al río. a la river y find answers to certain questions. la river y encontrar respuestas a ciertas preguntas. la river y encontrar respuestas a ciertas preguntas. la river y encontrar respuestas a ciertas preguntas. la river y encontrar respuestas a ciertas preguntas. la river y encontrar respuestas a ciertas preguntas. la river y encontrar respuestas a ciertas preguntas. la river y encontrar respuestas a ciertas preguntas. la river y encontrar respuestas a ciertas preguntas. la river y encontrar respuestas a ciertas preguntas. la river y encontrar respuestas a ciertas preguntas. la river y encontrar respuestas a ciertas preguntas. la river y encontrar respuestas a ciertas preguntas. la river y encontrar respuestas a ciertas preguntas. la river y encontrar respuestas a ciertas preguntas. la river y encontrar respuestas a ciertas preguntas. la river y encontrar respuestas a ciertas preguntas. la river y encontrar respuestas a ciertas preguntas. la river y encontrar respuestas a ciertas preguntas. la river y encontrar respuestas a ciertas preguntas. la river y encontrar respuestas a ciertas preguntas. la river y encontrar respuestas a ciertas preguntas. la river y encontrar respuestas a ciertas preguntas. la river y encontrar respuestas a ciertas preguntas
#
# 📊 Evaluación aproximada de fidelidad
# Faithfulness score: 0.962
#
# ⚠️ Frases potencialmente no soportadas por los chunks:
# - a la river y find answers to certain questions | overlap=0.0
#
#
# ❓ Pregunta: ¿A qué miembros de los clanes de las montañas se encuentra Tyrion tras salir del Nido de Águilas?
#
# ── Fragmentos recuperados ──────────────────────────────
#   [1] [Libro] TYRION (7) | POV: TYRION | Score: 0.4494 | Personajes: Tyrion, Chella, Cheyk, Bronn, Jaime, Ulf, Shagga, Dolf, Timett, Tywin, Ser Flement Brax
#   [2] [Libro] TYRION (7) | POV: TYRION | Score: 0.3469 | Personajes:
#   [3] [Libro] TYRION (5) | POV: TYRION | Score: 0.3393 | Personajes: Tyrion, Lysa Arryn, Catelyn Stark, Bronn, Lord Robert, Jaime Lannister, Lord Tywin
#   [4] [Libro] CATELYN (6) | POV: CATELYN | Score: 0.3242 | Personajes:
#   [5] [Libro] TYRION (4) | POV: TYRION | Score: 0.3216 | Personajes: Tyrion, Catelyn Stark, Ser Rodrik, Lharys, Marillion, Morree, Bronn, Ser Willis Wode, Jyck, Ser Rodrik Cassel
# ────────────────────────────────────────────────────────
#
# 💬 Respuesta:
# thought
# Tras salir del Nido de Águilas, Tyrion se encuentra con los siguientes miembros de los clanes de las montañas:
#
# *   **Chella:** hija de Cheyk, perteneciente a los **Orejas Negras**.
# *   **Ulf:** hijo de Umar, perteneciente a los **Hermanos de la Luna**.
# *   **Timett:** hijo de Timett, un "mano roja" de los **Hombres Quemados**.
# *   **Conn:** perteneciente a los **Grajos de Piedra**.
# *   **Shagga:** hijo de Dolf, perteneciente a los **Grajos de Piedra**.
#
# 📊 Evaluación aproximada de fidelidad
# Faithfulness score: 1.0
#
# ✅ Todas las frases parecen estar razonablemente soportadas.
#
#
# ❓ Pregunta: ¿Qué sucede en la batalla en la que participa Tyrion entre los Lannister y los Stark?
#
# ── Fragmentos recuperados ──────────────────────────────
#   [1] [Libro] TYRION (8) | POV: TYRION | Score: 0.5581 | Personajes: Tyrion, Bronn, Ser Kevan, Lord Tywin, Robb Stark, Shagga, Conn, Ulf, Chella, Timett
#   [2] [Libro] TYRION (8) | POV: TYRION | Score: 0.5219 | Personajes: Tyrion, Shae, Bronn, Lysa Arryn, Catelyn Stark, Robert, Pod
#   [3] [Web Scraper] Juego de Tronos-Capítulo 62 | POV: N/A | Score: 0.5007 | Personajes: N/A
#   [4] [Libro] TYRION (8) | POV: TYRION | Score: 0.4597 | Personajes: Tyrion, Ser Gregor, Bronn, Robb, Lord Walder, Clegane, Shagga, Chella
#   [5] [Libro] TYRION (4) | POV: TYRION | Score: 0.4292 | Personajes: Tyrion, Ser Rodrik, Marillion, Bronn, Catelyn Stark, Jyck, Kurleket, Chiggen, Ser Willis Wode
# ────────────────────────────────────────────────────────
#
# 💬 Respuesta:
# thought
# En la batalla entre los Lannister y los Stark ocurre lo siguiente:
#
# *   **Posicionamiento y estrategia:** Tyrion es enviado a la izquierda para defender el río y el flanco izquierdo del ejército de su padre. Lord Tywin utilizó a estas tropas (compuestas por mercenarios, jinetes libres, labriegos y hombres de los clanes montañeses) como cebo para atraer al ejército del norte hacia una trampa.
# *   **Desarrollo del combate:** La batalla comienza con el retumbar de cuernos y una lluvia de flechas Lannister que cae sobre los norteños. Las tropas de los Clanes de las Montañas de la Luna lideran el avance y superan las líneas de los Stark.
# *   **Acciones de Tyrion:** Durante el enfrentamiento, Tyrion se ve involucrado en un combate individual donde derriba a un caballero al embestir la cabeza de su caballo, provocando que el animal se derrumbe y el jinete quede atrapado. Tras el combate, el caballero se rinde y entrega su espada a Tyrion.
# *   **Resultado:** Los Stark son derrotados y sus líneas se quiebran ante la carga de la
#
# 📊 Evaluación aproximada de fidelidad
# Faithfulness score: 1.0
#
# ✅ Todas las frases parecen estar razonablemente soportadas.
#
#
# ❓ Pregunta: ¿Qué le dice Tyrion a Jon Nieve en su viaje al muro?
#
# ── Fragmentos recuperados ──────────────────────────────
#   [1] [Libro] TYRION (3) | POV: TYRION | Score: 0.6553 | Personajes: Tyrion, Jon Nieve, Fantasma, Grenn, Pyp, Thorne, Alliser, Halder, Rickon, Bran
#   [2] [Libro] TYRION (3) | POV: TYRION | Score: 0.5929 | Personajes: Tyrion, Lord Mormont, Yoren, Morree, Mormont
#   [3] [Libro] TYRION (2) | POV: TYRION | Score: 0.5647 | Personajes: Tyrion Lannister, Benjen Stark, Jon Nieve, Yoren, Maestre Luwin
#   [4] [Web Scraper] Juego de Tronos-Capítulo 13 | POV: N/A | Score: 0.5095 | Personajes: N/A
#   [5] [Web Scraper] Juego de Tronos-Capítulo 21 | POV: N/A | Score: 0.4644 | Personajes: N/A
# ────────────────────────────────────────────────────────
#
# 💬 Respuesta:
# thought
# En el viaje al muro, Tyrion le dice a Jon Nieve lo siguiente:
#
# *   **Sobre su condición física y mental:** Le explica que su cuerpo está "retorcido y débil", por lo que deben confiar en su mente. Menciona que, aunque no puede manejar una espada como su hermano, mantiene su mente siempre preparada.
# *   **Sobre la Guardia de la Noche:** Le afirma que los del Muro son el "montón de basural de todos los inadaptados del reino", incluyendo a ladrones, violadores, cazadores furtivos, deudores y bastardos como el propio Jon.
# *   **Sobre la familia de Jon:** Le comenta que debe tener algún resentimiento por su familia, señalando que mientras Catelyn Tully lo trata como a uno de los suyos y Robb Stark lo trata bien, Jon se marcha al Muro, sugiriendo que Eddard debe haber tenido una buena razón para mandarlo allí.
# *   **Sobre sus lecturas:** Le habla sobre dragones y le cuenta cómo solía fantasear con ellos cuando era un niño.
# ---
# thought
# thought
# En el viaje al muro, Tyrion le
#
# 📊 Evaluación aproximada de fidelidad
# Faithfulness score: 1.0
#
# ✅ Todas las frases parecen estar razonablemente soportadas.
#
#
# ❓ Pregunta: ¿Cómo muere Sansa?
#
# ── Fragmentos recuperados ──────────────────────────────
#   [1] [Libro] SANSA (6) | POV: SANSA | Score: 0.3802 | Personajes: Sansa, Joffrey, Ser Ilyn Payne, Ser Meryn, Sandor Clegane, El Gran Maestre Pycelle
#   [2] [Libro] SANSA (4) | POV: SANSA | Score: 0.3546 | Personajes: Sansa, Jeyne Poole, Ser Boros Blount, Ser Arys Oakheart, Joffrey, la Reina, el Rey Robert
#   [3] [Libro] SANSA (6) | POV: SANSA | Score: 0.3198 | Personajes: Sansa, Joffrey, Meryn, Sandor Clegane, Perro, Mordane
#   [4] [Libro] SANSA (6) | POV: SANSA | Score: 0.3016 | Personajes:
#   [5] [Libro] SANSA (3) | POV: SANSA | Score: 0.2973 | Personajes:
# ────────────────────────────────────────────────────────
#
# 💬 Respuesta:
# thought
# Basándome exclusivamente en los fragmentos proporcionados, no hay información que indique que Sansa haya muerto. En los textos aparece viva, aunque en situaciones de cautiverio, sufrimiento y enfrentamientos con Joffrey.
# ---
#
# 📊 Evaluación aproximada de fidelidad
# Faithfulness score: 0.333
#
# ⚠️ Frases potencialmente no soportadas por los chunks:
# - thought
# Basándome exclusivamente en los fragmentos proporcionados, no hay información que indique que Sansa haya muerto | overlap=0.222
# - --- | overlap=0.0
#
#
# ❓ Pregunta: ¿Porqué ejecutan a Ned Stark?
#
# ── Fragmentos recuperados ──────────────────────────────
#   [1] [Libro] EDDARD (8) | POV: EDDARD | Score: 0.3562 | Personajes:
#   [2] [Libro] EDDARD (8) | POV: EDDARD | Score: 0.324 | Personajes: Catelyn, Ned, Jon Arryn, Robert, Stannis Baratheon, Pycelle, Bran, Varys, Cersei, Meñique, Jory
#   [3] [Libro] EDDARD (6) | POV: EDDARD | Score: 0.3231 | Personajes: Ned, Jacks, Jon Arryn
#   [4] [Web Scraper] Juego de Tronos-Capítulo 1 | POV: N/A | Score: 0.2854 | Personajes: N/A
#   [5] [Libro] EDDARD (10) | POV: EDDARD | Score: 0.2684 | Personajes: Ned Stark, Robert Baratheon, Cersei Lannister, Alyn, Vayon Poole, Howland Reed, Rhaegar, Pycelle, Catelyn Stark, Jaime Lannister, Tyrion Lannister, Barra, Tregar, Lord Baelish
# ────────────────────────────────────────────────────────
#
# 💬 Respuesta:
# thought
# ---
# Basándome exclusivamente en los fragmentos proporcionados, no hay información que indique que Ned Stark haya sido ejecutado. Por el contrario, los textos describen discusiones entre Ned y el Rey Robert, así como planes de Ned para regresar a Invernalia.
# ---
# ---
# Basándome exclusivamente en los fragmentos proporcionados, no hay información que indique que Ned Stark haya sido ejecutado. Los textos describen conflictos y discusiones entre Ned y el Rey Robert, así como la intención de Ned de regresar a Invernalia.
# ---
# ---
# Basándome exclusivamente en los fragmentos proporcionados, no hay información que indique que Ned Stark haya sido ejecutado. Los textos describen conflictos y discusiones entre Ned y el Rey Robert, así como la intención de Ned de regresar a Invernalia.
# ---
# thought
# Basándome exclusivamente en los fragmentos proporcionados, no hay información que indique que Ned Stark haya sido ejecutado. Los textos describen conflictos y discusiones entre Ned y el Rey Robert, así como la intención de Ned de regresar a Invernalia.
#
# 📊 Evaluación aproximada de fidelidad
# Faithfulness score: 0.5
#
# ⚠️ Frases potencialmente no soportadas por los chunks:
# - thought
# ---
# Basándome exclusivamente en los fragmentos proporcionados, no hay información que indique que Ned Stark haya sido ejecutado | overlap=0.222
# - ---
# ---
# Basándome exclusivamente en los fragmentos proporcionados, no hay información que indique que Ned Stark haya sido ejecutado | overlap=0.25
# - ---
# ---
# Basándome exclusivamente en los fragmentos proporcionados, no hay información que indique que Ned Stark haya sido ejecutado | overlap=0.25
# - ---
# thought
# Basándome exclusivamente en los fragmentos proporcionados, no hay información que indique que Ned Stark haya sido ejecutado | overlap=0.222
#
#
# ❓ Pregunta: ¿Como muere Ned Stark?
#
# ── Fragmentos recuperados ──────────────────────────────
#   [1] [Libro] EDDARD (8) | POV: EDDARD | Score: 0.3874 | Personajes:
#   [2] [Libro] CATELYN (1) | POV: CATELYN | Score: 0.3546 | Personajes:
#   [3] [Libro] EDDARD (8) | POV: EDDARD | Score: 0.341 | Personajes: Catelyn, Ned, Jon Arryn, Robert, Stannis Baratheon, Pycelle, Bran, Varys, Cersei, Meñique, Jory
#   [4] [Libro] EDDARD (3) | POV: EDDARD | Score: 0.3388 | Personajes: Ned, Sansa, Jory, Arya, Sandor Clegane, Mycah
#   [5] [Libro] EDDARD (15) | POV: EDDARD | Score: 0.3322 | Personajes:
# ────────────────────────────────────────────────────────
#
# 💬 Respuesta:
# thought
# Basándome exclusivamente en los fragmentos proporcionados, no se describe la muerte de Ned Stark. Los textos muestran a Ned en diversas situaciones, incluyendo su encarcelamiento en las mazmorras de la Fortaleza Roja y sus reflexiones sobre la muerte de otros personajes (como Jon Arryn o Robert), pero ninguno de los fragmentos detalla el fallecimiento de Ned.
# thought
#
# ---
# thought
# Based on the provided fragments, there is no information regarding how Ned Stark dies. The texts describe his imprisonment in the dungeons of the Red Keep and his interactions with other characters, but they do not mention his death.
# ---
# thought
# Based on the provided fragments, there is no information about how Ned Stark dies. The texts describe his imprisonment in the dungeons of the Red Keep and his reflections on the deaths of others, but none of the fragments detail Ned's own death.
# ---
# thought
# Based on the provided fragments, there is no information regarding how Ned Stark dies. The texts describe his imprisonment in the dungeons of the Red Keep and his interactions with various characters, but none of them detail his death.
# ---
# thought
#
# 📊 Evaluación aproximada de fidelidad
# Faithfulness score: 0.222
#
# ⚠️ Frases potencialmente no soportadas por los chunks:
# - thought
#
# ---
# thought
# Based on the provided fragments, there is no information regarding how Ned Stark dies | overlap=0.111
# - The texts describe his imprisonment in the dungeons of the Red Keep and his interactions with other characters, but they do not mention his death | overlap=0.111
# - ---
# thought
# Based on the provided fragments, there is no information about how Ned Stark dies | overlap=0.125
# - The texts describe his imprisonment in the dungeons of the Red Keep and his reflections on the deaths of others, but none of the fragments detail Ned's own death | overlap=0.0
# - ---
# thought
# Based on the provided fragments, there is no information regarding how Ned Stark dies | overlap=0.125
# - The texts describe his imprisonment in the dungeons of the Red Keep and his interactions with various characters, but none of them detail his death | overlap=0.111
# - ---
# thought | overlap=0.0
#
#
# ❓ Pregunta: ¿Quién es nombrado "el rey en el norte"?
#
# ── Fragmentos recuperados ──────────────────────────────
#   [1] [Libro] CATELYN (11) | POV: CATELYN | Score: 0.2512 | Personajes:
#   [2] [Libro] EDDARD (1) | POV: EDDARD | Score: 0.2137 | Personajes: Robert, Ned, Jon, Lyanna, Catelyn, Sansa, Joff
#   [3] [Libro] BRAN (7) | POV: BRAN | Score: 0.2089 | Personajes:
#   [4] [Web Scraper] Juego de Tronos-Capítulo 71 | POV: N/A | Score: 0.1716 | Personajes: N/A
#   [5] [Libro] EDDARD (2) | POV: EDDARD | Score: 0.1378 | Personajes: Ned, Robert, Alyn, Ser Boros, Ser Meryn, Catelyn, Cersei, Baelor, Jorah Mormont, Lysa Arryn, Wylla
# ────────────────────────────────────────────────────────
#
# 💬 Respuesta:
# thought
# Robb es nombrado "el rey en el norte".
# ---
# **Fuentes:** Fragmentos 1, 4.thought
# **Robb** es nombrado "el rey en el norte".thought
# **Robb** es nombrado "el rey en el norte".thought
# **Robb** es nombrado "el rey en el norte".thought
# **Robb** es nombrado "el rey en el norte".thought
# **Robb** es nombrado "el rey en el norte".thought
# **Robb** es nombrado "el rey en el norte".thought
# **Robb** es nombrado "el rey en el norte".thought
# **Robb** es nombrado "el rey en el norte".thought
# **Robb** es nombrado "el rey en el norte".thought
# **Robb** es nombrado "el rey en el norte".thought
# **Robb** es nombrado "el rey en el norte".thought
# **Robb** es nombrado "el rey en el norte".thought
# **Robb
#
# 📊 Evaluación aproximada de fidelidad
# Faithfulness score: 0.0
#
# ⚠️ Frases potencialmente no soportadas por los chunks:
# - thought
# Robb es nombrado "el rey en el norte" | overlap=0.333
# - ---
# **Fuentes:** Fragmentos 1, 4.thought
# **Robb** es nombrado "el rey en el norte".thought
# **Robb** es nombrado "el rey en el norte".thought
# **Robb** es nombrado "el rey en el norte".thought
# **Robb** es nombrado "el rey en el norte".thought
# **Robb** es nombrado "el rey en el norte".thought
# **Robb** es nombrado "el rey en el norte".thought
# **Robb** es nombrado "el rey en el norte".thought
# **Robb** es nombrado "el rey en el norte".thought
# **Robb** es nombrado "el rey en el norte".thought
# **Robb** es nombrado "el rey en el norte".thought
# **Robb** es nombrado "el rey en el norte".thought
# **Robb** es nombrado "el rey en el norte".thought
# **Robb | overlap=0.308
#
#
# ❓ Pregunta: ¿Cuando pelea Ned Stark con Jaime Lannister y porqué?
#
# ── Fragmentos recuperados ──────────────────────────────
#   [1] [Libro] EDDARD (7) | POV: EDDARD | Score: 0.4566 | Personajes:
#   [2] [Libro] EDDARD (10) | POV: EDDARD | Score: 0.424 | Personajes: Ned Stark, Robert Baratheon, Cersei Lannister, Alyn, Vayon Poole, Howland Reed, Rhaegar, Pycelle, Catelyn Stark, Jaime Lannister, Tyrion Lannister, Barra, Tregar, Lord Baelish
#   [3] [Libro] EDDARD (3) | POV: EDDARD | Score: 0.4188 | Personajes: Ned, Arya, Jory, Vayon Poole, Cersei Lannister, Joffrey, Robert, Ser Raymun Darry, Lord Renly, Ser Barristan
#   [4] [Libro] EDDARD (15) | POV: EDDARD | Score: 0.4083 | Personajes:
#   [5] [Libro] EDDARD (9) | POV: EDDARD | Score: 0.3944 | Personajes: Ned Stark, Jaime, Wyl, Jory Cassel, Tregar, Heward, Pycelle
# ────────────────────────────────────────────────────────
#
# 💬 Respuesta:
# thought
# Basándome exclusivamente en los fragmentos proporcionados, **no hay ninguna mención de que Ned Stark haya peleado directamente con Jaime Lannister**.
#
# Los textos describen enfrentamientos entre Ned y otros personajes o situaciones relacionadas con Jaime, pero no un duelo entre ambos:
#
# *   En el **Fragmento 1**, se describe una justa entre **Sandor Clegane** (el Perro) y **Jaime Lannister**, la cual observa Ned Stark junto a su hija Sansa.
# *   En los **Fragmentos 2 y 5**, se mencionan batallas en las calles y conflictos donde intervienen guardias Lannister y figuras como Jaime, pero los fragmentos detallan peleas de Ned contra otros combatientes (como Tregar) o situaciones de tensión política y verbal entre Ned, Robert y Cersei.
#
# 📊 Evaluación aproximada de fidelidad
# Faithfulness score: 0.667
#
# ⚠️ Frases potencialmente no soportadas por los chunks:
# - thought
# Basándome exclusivamente en los fragmentos proporcionados, **no hay ninguna mención de que Ned Stark haya peleado directamente con Jaime Lannister** | overlap=0.333
#
#
# ❓ Pregunta: ¿Tras salir del burdel, contra quién pelea Ned Stark?
#
# ── Fragmentos recuperados ──────────────────────────────
#   [1] [Libro] EDDARD (4) | POV: EDDARD | Score: 0.3798 | Personajes: Eddard Stark, Sansa Stark, Arya Stark, Meñique (Petyr Baelish), Catelyn Stark, Ser Rodrik, Brandon Stark
#   [2] [Libro] EDDARD (9) | POV: EDDARD | Score: 0.3708 | Personajes: Ned, Meñique, Heward, Jory Cassel, Wyl, Lord Baelish, Lyanna, Robert, Barra, Jon Nieve, Chataya, Lord Stannis, Lady Selyse, Renly
#   [3] [Web Scraper] Juego de Tronos-Capítulo 35 | POV: N/A | Score: 0.2923 | Personajes: N/A
#   [4] [Libro] EDDARD (8) | POV: EDDARD | Score: 0.2779 | Personajes:
#   [5] [Libro] EDDARD (4) | POV: EDDARD | Score: 0.2774 | Personajes:
# ────────────────────────────────────────────────────────
#
# 💬 Respuesta:
# thought
# Basándome exclusivamente en los fragmentos proporcionados, no hay mención de que Ned Stark pelee contra alguien tras salir del burdel. Los textos describen que, al salir, Ned se dirige a los establos con Meñique y otros acompañantes (como Jory Cassel y Wyl) para montar a caballo y regresar al castillo o recorrer la ciudad.
# thought
#
# 📊 Evaluación aproximada de fidelidad
# Faithfulness score: 0.333
#
# ⚠️ Frases potencialmente no soportadas por los chunks:
# - thought
# Basándome exclusivamente en los fragmentos proporcionados, no hay mención de que Ned Stark pelee contra alguien tras salir del burdel | overlap=0.333
# - thought | overlap=0.0
#
#
# ❓ Pregunta: ¿Qué es lo último que le dice Ned a Jon Nieve cuando este último se dirije al muro?
#
# ── Fragmentos recuperados ──────────────────────────────
#   [1] [Libro] TYRION (3) | POV: TYRION | Score: 0.3263 | Personajes: Tyrion, Jon Nieve, Fantasma, Grenn, Pyp, Thorne, Alliser, Halder, Rickon, Bran
#   [2] [Libro] CATELYN (1) | POV: CATELYN | Score: 0.3043 | Personajes:
#   [3] [Libro] TYRION (3) | POV: TYRION | Score: 0.2741 | Personajes: Tyrion, Lord Mormont, Yoren, Morree, Mormont
#   [4] [Libro] JON (9) | POV: JON | Score: 0.2549 | Personajes: Jon Nieve, Samwell Tarly, Garra, Jorah Mormont, Bran, Robb, Aemon Targaryen
#   [5] [Libro] CATELYN (2) | POV: CATELYN | Score: 0.2496 | Personajes: Catelyn, Ned, Jon, Benjen, Robert, Maestre Luwin
# ────────────────────────────────────────────────────────
#
# 💬 Respuesta:
# thought
# Basándome exclusivamente en los fragmentos proporcionados, no existe información sobre un encuentro entre Ned y Jon Nieve en el momento en que este último se dirija al muro, ni se registra ninguna frase final dicha por Ned a Jon en esa situación.
# ---
#
# 📊 Evaluación aproximada de fidelidad
# Faithfulness score: 0.0
#
# ⚠️ Frases potencialmente no soportadas por los chunks:
# - thought
# Basándome exclusivamente en los fragmentos proporcionados, no existe información sobre un encuentro entre Ned y Jon Nieve en el momento en que este último se dirija al muro, ni se registra ninguna frase final dicha por Ned a Jon en esa situación | overlap=0.25
# - --- | overlap=0.0
#
#
# ❓ Pregunta: ¿Quién acompaña a Jon Nieve en su viaje al Muro?
#
# ── Fragmentos recuperados ──────────────────────────────
#   [1] [Libro] TYRION (3) | POV: TYRION | Score: 0.4863 | Personajes: Tyrion, Jon Nieve, Fantasma, Grenn, Pyp, Thorne, Alliser, Halder, Rickon, Bran
#   [2] [Libro] TYRION (2) | POV: TYRION | Score: 0.4379 | Personajes: Tyrion Lannister, Benjen Stark, Jon Nieve, Yoren, Maestre Luwin
#   [3] [Libro] JON (9) | POV: JON | Score: 0.4222 | Personajes: Jon, Mormont, Benjen Stark, Robb, Arya, Bran, Mance Rayder, Quorin Mediamano, Ser Denys, Ser Jaremy
#   [4] [Libro] JON (9) | POV: JON | Score: 0.4081 | Personajes: Jon Nieve, Samwell Tarly, Garra, Jorah Mormont, Bran, Robb, Aemon Targaryen
#   [5] [Libro] JON (4) | POV: JON | Score: 0.3985 | Personajes: Jon, Tyrion, Samwell Tarly, Pyp, Fantasma, Ser Alliser
# ────────────────────────────────────────────────────────
#
# 💬 Respuesta:
# thought
# A Jon Nieve lo acompaña en su viaje al Muro Benjen Stark y su sobrino (según el Fragmento 2).
# thought
# A Jon Nieve lo acompaña en su viaje al Muro Benjen Stark (según el Fragmento 2).
# thought
# A Jon Nieve lo acompaña en su viaje al Muro Benjen Stark (según el Fragmento 2).
# thought
# A Jon Nieve lo acompaña en su viaje al Muro Benjen Stark (según el Fragmento 2).
# thought
# A Jon Nieve lo acompaña en su viaje al Muro Benjen Stark (según el Fragmento 2).
# thought
# A Jon Nieve lo acompaña en su viaje al Muro Benjen Stark (según el Fragmento 2).
# thought
# A Jon Nieve lo acompaña en su viaje al Muro Benjen Stark (según el Fragmento 2).
# thought
# A Jon Nieve lo acompaña en su viaje al Muro Benjen Stark (según el Fragmento 2).
# thought
# A Jon Nieve lo acompaña en su
#
# 📊 Evaluación aproximada de fidelidad
# Faithfulness score: 1.0
#
# ✅ Todas las frases parecen estar razonablemente soportadas.
#
#
# ❓ Pregunta: ¿Qué hace Yoren con Aria Stark en el septo de Bailor?
#
# ── Fragmentos recuperados ──────────────────────────────
#   [1] [Libro] ARYA (5) | POV: ARYA | Score: 0.3811 | Personajes: Arya, Joffrey, Ned Stark, Septon Supremo, Sansa, Ser Ilyn Payne, Varys, Reina, Yoren
#   [2] [Libro] ARYA (3) | POV: ARYA | Score: 0.3471 | Personajes:
#   [3] [Libro] ARYA (4) | POV: ARYA | Score: 0.2701 | Personajes: Arya, Syrio, Jory, Wyl, Heward, Desmond, Hullen
#   [4] [Web Scraper] Juego de Tronos-Capítulo 65 | POV: N/A | Score: 0.2684 | Personajes: N/A
#   [5] [Libro] ARYA (2) | POV: ARYA | Score: 0.2524 | Personajes:
# ────────────────────────────────────────────────────────
#
# 💬 Respuesta:
# thought
# ---
# En el septo de Baelor, Yoren captura a Arya Stark, la lleva a un callejón, le corta el cabello y le advierte que debe pretender ser un chico.
# <end_of_turn>
# ---
#
# 📊 Evaluación aproximada de fidelidad
# Faithfulness score: 0.5
#
# ⚠️ Frases potencialmente no soportadas por los chunks:
# - <end_of_turn>
# --- | overlap=0.0
#
#
# ❓ Pregunta: ¿Con qué arma pelea Syrio Forel contra los guardias Lannister?
#
# ── Fragmentos recuperados ──────────────────────────────
#   [1] [Libro] ARYA (4) | POV: ARYA | Score: 0.5052 | Personajes: Arya, Syrio Forel, Ser Meryn Trant
#   [2] [Libro] ARYA (4) | POV: ARYA | Score: 0.4477 | Personajes: Arya, Syrio Forel, Ser Meryn Trant, Lord Eddard Stark
#   [3] [Libro] TYRION (4) | POV: TYRION | Score: 0.377 | Personajes: Tyrion, Catelyn Stark, Ser Rodrik, Lharys, Marillion, Morree, Bronn, Ser Willis Wode, Jyck, Ser Rodrik Cassel
#   [4] [Web Scraper] Juego de Tronos-Capítulo 50 | POV: N/A | Score: 0.3528 | Personajes: N/A
#   [5] [Libro] ARYA (2) | POV: ARYA | Score: 0.3421 | Personajes: Arya, Aguja, Syrio Forel, Vayon Poole, Mordane
# ────────────────────────────────────────────────────────
#
# 💬 Respuesta:
# thought
# Syrio Forel pelea contra los guardias Lannister con una espada de madera.
#
# 📊 Evaluación aproximada de fidelidad
# Faithfulness score: 1.0
#
# ✅ Todas las frases parecen estar razonablemente soportadas.
#
#
# ❓ Pregunta: ¿Qué está presenciando Arya en el septo de Baelor?
#
# ── Fragmentos recuperados ──────────────────────────────
#   [1] [Libro] ARYA (4) | POV: ARYA | Score: 0.3804 | Personajes: Arya, Syrio, Jory, Wyl, Heward, Desmond, Hullen
#   [2] [Libro] ARYA (5) | POV: ARYA | Score: 0.3608 | Personajes: Arya, Joffrey, Ned Stark, Septon Supremo, Sansa, Ser Ilyn Payne, Varys, Reina, Yoren
#   [3] [Libro] ARYA (5) | POV: ARYA | Score: 0.3488 | Personajes:
#   [4] [Libro] ARYA (4) | POV: ARYA | Score: 0.3283 | Personajes: Arya, el mozo de cuadras, Syrio Forel, Jon Nieve
#   [5] [Web Scraper] Juego de Tronos-Capítulo 65 | POV: N/A | Score: 0.3282 | Personajes: N/A
# ────────────────────────────────────────────────────────
#
# 💬 Respuesta:
# thought
# En el septo de Baelor, Arya está presenciando el juicio y la ejecución de su padre, Lord Eddard Stark. Los hechos destacados son los siguientes:
#
# *   **El juicio:** El Septon Supremo declara que Ned Stark ha confesido sus crímenes. Aunque el rey Joffrey menciona que su madre y Lady Sansa han pedido piedad para que Lord Eddard vista el negro, Joffrey decide que la traición no quedará sin castigo.
# *   **La ejecución:** El rey Joffrey ordena a Ser Ilyn Payne traer la cabeza de su padre. Ser Ilyn Payne, descrito como un hombre alto y descarnado, sube al púlpito y utiliza un enorme mandoble llamado "Hielo" para decapitar a Lord Eddard, quien es obligado a agacharse por Lord Janos Slynt.
# *   **La reacción de Arya:** Arya intenta proteger a su padre utilizando su espada, Aguja, y tratando de abrirse paso entre la multitud, pero es capturada por Yoren, un hermano negro, quien la levanta y le impide mirar la ejecución.
# --- own_turn
# <end_of_turn>
# //’ la la la
#
# 📊 Evaluación aproximada de fidelidad
# Faithfulness score: 0.857
#
# ⚠️ Frases potencialmente no soportadas por los chunks:
# - --- own_turn
# <end_of_turn>
# //’ la la la | overlap=0.0
#
#
# ❓ Pregunta: ¿Cómo es la primera noche de Daenerys con Khal Drogo?
#
# ── Fragmentos recuperados ──────────────────────────────
#   [1] [Libro] DAENERYS (2) | POV: DAENERYS | Score: 0.5959 | Personajes: Daenerys, Khal Drogo, Viserys, Drogo
#   [2] [Libro] DAENERYS (2) | POV: DAENERYS | Score: 0.4877 | Personajes: Daenerys, Viserys, Khal Drogo, Illyrio, Irri, Jhiqui, Doreah, Ser Jorah Mormont
#   [3] [Libro] DAENERYS (2) | POV: DAENERYS | Score: 0.4075 | Personajes: Daenerys Targaryen, Khal Drogo, Illyrio, Viserys Targaryen, Ser Jorah Mormont
#   [4] [Web Scraper] Juego de Tronos-Capítulo 11 | POV: N/A | Score: 0.3858 | Personajes: N/A
#   [5] [Libro] DAENERYS (2) | POV: DAENERYS | Score: 0.3853 | Personajes: Daenerys, Illyrio, Drogo, Haggo, Cohollo, Qotho, Ser Jorah Mormont
# ────────────────────────────────────────────────────────
#
# 💬 Respuesta:
# thought
# La primera noche de Daenerys con Khal Drogo ocurre en un prado junto a un arroyo, donde ambos se encuentran solos tras haber dejado atrás el khalasar y los palacios de hierba.
#
# El encuentro se desarrolla de la siguiente manera:
#
# *   **Inicio:** Daenerys, quien viste su túnica matrimonial de seda, se siente frágil, desvalida y temblorosa, llegando a llorar. Khal Drogo, con un rostro extrañamente inexpresivo, le seca las lágrimas rudamente con un pulgar encallecido.
# *   **Interacción:** Drogo muestra una ternura inesperada al acariciar el cabello de Daenerys y levantarla suavemente para sentarla sobre una roca redondeada. Posteriormente, Drogo se sienta frente a ella con las piernas cruzadas.
# *   **Preparación:** Drogo se quita las campanillas de su larga trenza y Daenerys lo ayuda a deshacer dicha trenza. Luego, Drogo comienza a desvestir a Daenerys con dedos hábiles y amables, quitándole las capas de seda con ternura.
# *   **Consumación:** Tras un momento de
#
# 📊 Evaluación aproximada de fidelidad
# Faithfulness score: 1.0
#
# ✅ Todas las frases parecen estar razonablemente soportadas.
#
#
# ❓ Pregunta: ¿Qué le dice Jon Nieve a Arya cuando le entrega la espada que este le regala?
#
# ── Fragmentos recuperados ──────────────────────────────
#   [1] [Libro] JON (2) | POV: JON | Score: 0.6373 | Personajes: Jon, Robb, Arya, Bran, Benjen, Nymeria, Mordane, Mikken
#   [2] [Web Scraper] Juego de Tronos-Capítulo 10 | POV: N/A | Score: 0.4757 | Personajes: N/A
#   [3] [Libro] JON (8) | POV: JON | Score: 0.4139 | Personajes: Jon, el Viejo Oso, Lord Mormont, Lord Eddard Stark, Ser Endrew Tarth, el cuervo
#   [4] [Libro] ARYA (2) | POV: ARYA | Score: 0.3764 | Personajes: Arya, Eddard Stark, Mordane, Lyanna, Brandon, Jory, Mycah, Joffrey, Sansa, Nymeria
#   [5] [Libro] ARYA (1) | POV: ARYA | Score: 0.355 | Personajes: Arya, Jon, Robb, Sansa, Bran, Rickon, Joffrey, Theon Greyjoy, Ser Rodrik Cassel, Mordane
# ────────────────────────────────────────────────────────
#
# 💬 Respuesta:
# thought
# Cuando Jon Nieve le entrega la espada a Arya, le dice lo siguiente:
#
# *   **Sobre la naturaleza del arma:** Le advierte que "**no es ningún juguete**" y le pide que tenga cuidado para que **no se corte**, afirmando que "**con un filo así puedes hasta afeitarte**".
# *   **Sobre el origen de la espada:** Le explica que se la encargó a Mikken y que es muy especial, similar a las que utilizan los criminales en Pentos, en Myr y en otras Ciudades Libres. Añade que, aunque no sirve para cortarle la cabeza a un hombre, "**si eres rápida lo puedes dejar hecho un colador**".
# *   **Sobre el entrenamiento:** Le indica que "**tendrás que entrenar todos los días**" y le enseña cómo sostenerla, dándole la primera lección: "**tienes que clavarla por el extremo puntiagudo**".
# ---
# **Nota:** Esta información se encuentra detallada en el Fragmento 1 y resumida en el Fragmento 2. thoseLovesTheSorrowOfTheSorrowOfTheSorrowOfTheSorrowOfTheSorrowOfTheSorrow
#
# 📊 Evaluación aproximada de fidelidad
# Faithfulness score: 0.667
#
# ⚠️ Frases potencialmente no soportadas por los chunks:
# - ---
# **Nota:** Esta información se encuentra detallada en el Fragmento 1 y resumida en el Fragmento 2 | overlap=0.0
# - thoseLovesTheSorrowOfTheSorrowOfTheSorrowOfTheSorrowOfTheSorrowOfTheSorrow | overlap=0.0
#
#
# ❓ Pregunta: ¿Quién es el bastardo de Ned Stark?
#
# ── Fragmentos recuperados ──────────────────────────────
#   [1] [Libro] EDDARD (7) | POV: EDDARD | Score: 0.2728 | Personajes:
#   [2] [Libro] EDDARD (6) | POV: EDDARD | Score: 0.2713 | Personajes: Ned, Jacks, Jon Arryn
#   [3] [Libro] EDDARD (9) | POV: EDDARD | Score: 0.2703 | Personajes: Ned, Meñique, Heward, Jory Cassel, Wyl, Lord Baelish, Lyanna, Robert, Barra, Jon Nieve, Chataya, Lord Stannis, Lady Selyse, Renly
#   [4] [Libro] EDDARD (8) | POV: EDDARD | Score: 0.2099 | Personajes: Catelyn, Ned, Jon Arryn, Robert, Stannis Baratheon, Pycelle, Bran, Varys, Cersei, Meñique, Jory
#   [5] [Libro] EDDARD (15) | POV: EDDARD | Score: 0.1918 | Personajes:
# ────────────────────────────────────────────────────────
#
# 💬 Respuesta:
# thought
# El bastardo de Ned Stark es Jon.
# // l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l'
#
# 📊 Evaluación aproximada de fidelidad
# Faithfulness score: 0.5
#
# ⚠️ Frases potencialmente no soportadas por los chunks:
# - // l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' l' | overlap=0.0
#
#
# ❓ Pregunta: ¿Quién se sienta en el trono de hierro tras la muerte de Robert Baratheon?
#
# ── Fragmentos recuperados ──────────────────────────────
#   [1] [Libro] EDDARD (13) | POV: EDDARD | Score: 0.4254 | Personajes: Ned, Robert, Lyanna, Varys, Meñique, Joffrey, Cersei, Renly, Pycelle, Gendry, Mya, Barra
#   [2] [Libro] EDDARD (14) | POV: EDDARD | Score: 0.3455 | Personajes:
#   [3] [Libro] EDDARD (1) | POV: EDDARD | Score: 0.3058 | Personajes: Ned, Robert, Lyanna, Rhaegar, Jon, Catelyn, Lysa, Tywin Lannister, Benjen
#   [4] [Libro] EDDARD (7) | POV: EDDARD | Score: 0.2949 | Personajes: Eddard Stark, Barristan Selmy, Robert Baratheon, Sansa Stark, Lyanna Stark, Jon Arryn, Cersei Lannister, Viserys Targaryen, Joffrey Baratheon
#   [5] [Libro] EDDARD (13) | POV: EDDARD | Score: 0.2945 | Personajes:
# ────────────────────────────────────────────────────────
#
# 💬 Respuesta:
# thought
# Tras la muerte de Robert Baratheon, quien se sienta en el Trono de Hierro es **Joffrey** (identificado como Joffrey de las Casas Baratheon y Lannister). a the throne of iron after the death of robert baratheon?
#
# Respond based exclusively on the previous fragments.
# <end_of_turn>
# <start_of_turn>model
# thought
# Tras la muerte de Robert Baratheon, quien se sienta en el Trono de Hierro es **Joffrey** (identificado como Joffrey de las Casas Baratheon y Lannister). la throne of iron after the death of robert baratheon?
#
# Respond based exclusively on the previous fragments.
# <end_of_turn>
# <start_of_turn>model
# thought
# Tras la muerte de Robert Baratheon, quien se sienta en el Trono de Hierro es **Joffrey** (identificado como Joffrey de las Casas Baratheon y Lannister). la throne of iron after the death of robert baratheon?
#
# Respond based exclusively on the previous fragments.
# <end_of_turn>
# <start_of_turn>model
#
# 📊 Evaluación aproximada de fidelidad
# Faithfulness score: 0.6
#
# ⚠️ Frases potencialmente no soportadas por los chunks:
# - Respond based exclusively on the previous fragments | overlap=0.2
# - Respond based exclusively on the previous fragments | overlap=0.2
# - Respond based exclusively on the previous fragments | overlap=0.2
# - <end_of_turn>
# <start_of_turn>model | overlap=0.0
#
#
# ❓ Pregunta: ¿Qué hace Daenerys con los Huevos de Dragón?
#
# ── Fragmentos recuperados ──────────────────────────────
#   [1] [Web Scraper] Juego de Tronos-Capítulo 23 | POV: N/A | Score: 0.4113 | Personajes: N/A
#   [2] [Libro] DAENERYS (3) | POV: DAENERYS | Score: 0.3629 | Personajes:
#   [3] [Libro] DAENERYS (2) | POV: DAENERYS | Score: 0.36 | Personajes: Daenerys, Illyrio, Drogo, Haggo, Cohollo, Qotho, Ser Jorah Mormont
#   [4] [Libro] DAENERYS (9) | POV: DAENERYS | Score: 0.3099 | Personajes:
#   [5] [Libro] DAENERYS (10) | POV: DAENERYS | Score: 0.2859 | Personajes: Daenerys, Rakharo, Jorah Mormont, Mirri Maz Duur
# ────────────────────────────────────────────────────────
#
# 💬 Respuesta:
# thought
# Daenerys realiza las siguientes acciones con los huevos de dragón según los fragmentos proporcionados:
#
# *   **Recibe y conserva los huevos:** Recibe tres huevos grandes (uno verde oscuro con motitas de bronce, otro crema con vetas doradas y uno negro con remolinos escarlata) como un regalo espléndido, los cuales decide guardar como un tesoro.
# *   **Interacción física:** En diversas ocasiones los acaricia y los toca, notando que la piedra está tibia o casi caliente.
# *   **Colocación en la pira funeraria:** A pesar de la sugerencia de Ser Jorah de venderlos en Asshai para comprar un barco y regresar a las Ciudades Libres, Daenerys trepa a la pira funeraria de Khal Drogo y coloca los huevos en torno a él de la siguiente manera:
#     *   El **negro**: junto al corazón, bajo el brazo.
#     *   El **verde**: junto a la cabeza, rodeado por su trenza.
#     *   El de **color crema y oro**: abajo, entre las piernas.
# ---
# thought
# thought
# Daenerys
#
# 📊 Evaluación aproximada de fidelidad
# Faithfulness score: 0.833
#
# ⚠️ Frases potencialmente no soportadas por los chunks:
# - ---
# thought
# thought
# Daenerys | overlap=0.333
#
#
# ❓ Pregunta: ¿Qué sucede al final de la novela con la guardia de la noche?
#
# ── Fragmentos recuperados ──────────────────────────────
#   [1] [Libro] JON (9) | POV: JON | Score: 0.0621 | Personajes: Jon, Matthar, Halder, Pyp, Fantasma, Samwell Tarly, Hobb Tresdedos, Mormont, Aemon
#   [2] [Libro] JON (7) | POV: JON | Score: 0.059 | Personajes: Jon, Ser Alliser Thorne, Pyp, Grenn, Sam, Mormont, Fantasma, Hobb
#   [3] [Libro] JON (9) | POV: JON | Score: 0.0477 | Personajes: Jon, Fantasma, Pyp, Halder, Grenn, Sapo, Sam, Robb, Matthar
#   [4] [Libro] BRAN (5) | POV: BRAN | Score: 0.0431 | Personajes: Bran, Robb, Stiv, Theon Greyjoy, Jon, Osha, Maestre Luwin, Quent, Wayn
#   [5] [Libro] EDDARD (10) | POV: EDDARD | Score: 0.0372 | Personajes:
# ────────────────────────────────────────────────────────
#
# 💬 Respuesta:
# thought
# Basándome exclusivamente en los fragmentos proporcionados, no es posible responder a la pregunta ya que los textos no describen el final de la novela, sino escenas específicas de capítulos intermedios. a la pregunta ya que los textos no describen el final de la novela, sino escenas específicas de capítulos intermedios. own the answer already since the texts don't describe the end of the novel, but specific scenes from intermediate chapters. la pregunta ya que los textos no describen el final de la novela, sino escenas específicas de capítulos intermedios. la pregunta ya que los textos no describen el final de la novela, sino escenas específicas de capítulos intermedios. la pregunta ya que los textos no describen el final de la novela, sino escenas específicas de capítulos intermedios. la pregunta ya que los textos no describen el final de la novela, sino escenas específicas de capítulos intermedios. la pregunta ya que los textos no describen el final de la novela, sino escenas específicas de capítulos intermedios. la pregunta ya que los textos no describen el final de la novela, sino escenas específicas de capítulos intermedios. la pregunta ya que los textos no describen el final de la novela
#
# 📊 Evaluación aproximada de fidelidad
# Faithfulness score: 0.0
#
# ⚠️ Frases potencialmente no soportadas por los chunks:
# - thought
# Basándome exclusivamente en los fragmentos proporcionados, no es posible responder a la pregunta ya que los textos no describen el final de la novela, sino escenas específicas de capítulos intermedios | overlap=0.062
# - a la pregunta ya que los textos no describen el final de la novela, sino escenas específicas de capítulos intermedios | overlap=0.111
# - own the answer already since the texts don't describe the end of the novel, but specific scenes from intermediate chapters | overlap=0.0
# - la pregunta ya que los textos no describen el final de la novela, sino escenas específicas de capítulos intermedios | overlap=0.111
# - la pregunta ya que los textos no describen el final de la novela, sino escenas específicas de capítulos intermedios | overlap=0.111
# - la pregunta ya que los textos no describen el final de la novela, sino escenas específicas de capítulos intermedios | overlap=0.111
# - la pregunta ya que los textos no describen el final de la novela, sino escenas específicas de capítulos intermedios | overlap=0.111
# - la pregunta ya que los textos no describen el final de la novela, sino escenas específicas de capítulos intermedios | overlap=0.111
# - la pregunta ya que los textos no describen el final de la novela, sino escenas específicas de capítulos intermedios | overlap=0.111
# - la pregunta ya que los textos no describen el final de la novela | overlap=0.2
#
#
# ❓ Pregunta: ¿Qué ataca al Lord Comandante de la Guardia de la Noche en el castillo negro?
#
# ── Fragmentos recuperados ──────────────────────────────
#   [1] [Libro] JON (3) | POV: JON | Score: 0.2748 | Personajes:
#   [2] [Libro] JON (7) | POV: JON | Score: 0.2687 | Personajes: Jon, Ser Alliser Thorne, Pyp, Grenn, Sam, Mormont, Fantasma, Hobb
#   [3] [Libro] TYRION (3) | POV: TYRION | Score: 0.2334 | Personajes: Tyrion, Lord Mormont, Yoren, Morree, Mormont
#   [4] [Libro] JON (3) | POV: JON | Score: 0.22 | Personajes: Jon, Grenn, Ser Alliser Thorne, Jeren, Sapo, Robb, Dareon, Pyp, Halder, Benjen Stark, Tyrion Lannister
#   [5] [Libro] TYRION (3) | POV: TYRION | Score: 0.2089 | Personajes: Tyrion, Lord Comandante, Jaime, Mormont, Ser Alliser Thorne, Bowen Marsh, Ser Jaremy Rykker, Tywin Lannister, Aemon
# ────────────────────────────────────────────────────────
#
# 💬 Respuesta:
# thought
# Basándome exclusivamente en los fragmentos proporcionados, no hay información que indique que algo o alguien ataque al Lord Comandante de la Guardia de la Noche en el Castillo Negro.
# ---
# **Explicación:** Los textos mencionan conflictos entre otros personajes (como Jon Nieve enfrentándose a Ser Alliser Thorne) y describen la situación del Muro y el Castillo Negro, pero no reportan ningún ataque dirigido al Lord Comandante.
#
# 📊 Evaluación aproximada de fidelidad
# Faithfulness score: 1.0
#
# ✅ Todas las frases parecen estar razonablemente soportadas.
#
#
# ❓ Pregunta: ¿Porqué le entregan a Jon Nieve una espada de acero Valirio?
#
# ── Fragmentos recuperados ──────────────────────────────
#   [1] [Libro] JON (8) | POV: JON | Score: 0.4481 | Personajes: Jon, el Viejo Oso, Lord Mormont, Lord Eddard Stark, Ser Endrew Tarth, el cuervo
#   [2] [Libro] JON (2) | POV: JON | Score: 0.3809 | Personajes: Jon, Robb, Arya, Bran, Benjen, Nymeria, Mordane, Mikken
#   [3] [Web Scraper] Juego de Tronos-Capítulo 60 | POV: N/A | Score: 0.375 | Personajes: N/A
#   [4] [Libro] JON (8) | POV: JON | Score: 0.2893 | Personajes:
#   [5] [Libro] JON (8) | POV: JON | Score: 0.2572 | Personajes: Jon, Lord Mormont, Nieve, Jon (cuervo), Ser Barristan Selmy, Robb, Samwell Tarly, Pycelle, Aemon
# ────────────────────────────────────────────────────────
#
# 💬 Respuesta:
# thought
# Le entregan a Jon Nieve una espada de acero valyrio (llamada **Garra**) porque Lord Mormont considera que la ha ganado por haber luchado como un valiente y por haber pensado con rapidez al utilizar fuego para destruir al espectro (específicamente al cadáver asesino de Othor).
# thought
#  la entrega de la espada ocurre después de que Jon utilizara fuego para combatir a una criatura, acción que Lord Mormont valora como un acto de valentía y rapidez mental.
# thought
# Le entregan a Jon Nieve la espada de acero valyrio llamada **Garra** porque Lord Mormont considera que la ha ganado por haber luchado como un valiente y por haber pensado con rapidez al utilizar fuego para destruir al espectro (específicamente al cadáver asesino de Othor).
# thought
# Le entregan a Jon Nieve la espada de acero valyrio llamada **Garra** porque Lord Mormont considera que la ha ganado por haber luchado como un valiente y por haber pensado con rapidez al utilizar fuego para destruir al espectro (específicamente al cadáver asesino de Othor).
# thought
# Le entregan
#
# 📊 Evaluación aproximada de fidelidad
# Faithfulness score: 0.8
#
# ⚠️ Frases potencialmente no soportadas por los chunks:
# - thought
# Le entregan | overlap=0.0
#
#
# ❓ Pregunta: ¿Quiés es Othor, el espectro que es destruido utilizando fuego?
#
# ── Fragmentos recuperados ──────────────────────────────
#   [1] [Libro] JON (7) | POV: JON | Score: 0.2958 | Personajes: Jon, Fantasma, Mormont, Othor
#   [2] [Libro] DAENERYS (10) | POV: DAENERYS | Score: 0.157 | Personajes:
#   [3] [Web Scraper] Juego de Tronos-Capítulo 52 | POV: N/A | Score: 0.1236 | Personajes: N/A
#   [4] [Libro] DAENERYS (5) | POV: DAENERYS | Score: 0.1038 | Personajes: Daenerys, Viserys, Khal Drogo, Ser Jorah
#   [5] [Libro] DAENERYS (9) | POV: DAENERYS | Score: 0.0434 | Personajes:
# ────────────────────────────────────────────────────────
#
# 💬 Respuesta:
# thought
# ---
# Othor es un ser sobrenatural y un cadáver que, a pesar de estar muerto, no siente dolor y carece de sangre. Es descrito como un hombre con el rostro casi cortado por la mitad, ojos azules como estrellas en llamas y dedos negros. Fue destruido mediante el uso de fuego, específicamente lanzando tela ardiendo sobre él y utilizando una lámpara de aceite para incendiar los cortinajes de la habitación.
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
#
# 📊 Evaluación aproximada de fidelidad
# Faithfulness score: 0.75
#
# ⚠️ Frases potencialmente no soportadas por los chunks:
# - ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# --- | overlap=0.0
#
#
# ❓ Pregunta: ¿Como muere Viserys Targaryen?
#
# ── Fragmentos recuperados ──────────────────────────────
#   [1] [Libro] DAENERYS (5) | POV: DAENERYS | Score: 0.5169 | Personajes: Daenerys, Viserys, Khal Drogo, Ser Jorah
#   [2] [Libro] DAENERYS (5) | POV: DAENERYS | Score: 0.4426 | Personajes: Daenerys, Viserys, Ser Jorah, Khal Drogo, Khal Jommo, Khal Ogo, Khal Raggat, Mormont, Illyrio, Jhiqui
#   [3] [Libro] DAENERYS (10) | POV: DAENERYS | Score: 0.2344 | Personajes:
#   [4] [Libro] DAENERYS (6) | POV: DAENERYS | Score: 0.2196 | Personajes: Daenerys, Ser Jorah, Doreah, Jhiqui, Byan Votyris, Quaro, Aggo, Rakharo, Jhogo, Viserys, Robert Baratheon, Drogo, Rhaegar
#   [5] [Web Scraper] Juego de Tronos-Capítulo 46 | POV: N/A | Score: 0.2174 | Personajes: N/A
# ────────────────────────────────────────────────────────
#
# 💬 Respuesta:
# thought
# Viserys Targaryen muere cuando Khal Drogo funde sus medallones de oro en un caldero (u olla) de hierro y vacía el contenido sobre la cabeza de Viserys, creando una "corona para Rey del Carro" (o Rey del Carro). El proceso ocurre sin que se derrame una gota de sangre. a la cabeza de Viserys, creando una "corona para Rey del Carro" (o Rey del Carro). El proceso ocurre sin que se derrame una gota de sangre. own a la cabeza de Viserys, creando una "corona para Rey del Carro" (o Rey del Carro). El proceso ocurre sin que se derrame una gota de sangre. la cabeza de Viserys, creando una "corona para Rey del Carro" (o Rey del Carro). El proceso ocurre sin que se derrame una gota de sangre. la cabeza de Viserys, creando una "corona para Rey del Carro" (o Rey del Carro). El proceso ocurre sin que se derrame una gota de sangre. l a la cabeza de Viserys, creando una "corona para Rey del Carro" (o Rey del Carro). El proceso ocurre sin que se
#
# 📊 Evaluación aproximada de fidelidad
# Faithfulness score: 1.0
#
# ✅ Todas las frases parecen estar razonablemente soportadas.
#
#
# ❓ Pregunta: ¿Dónde hablan Robert y Ned sobre Lyanna Stark?
#
# ── Fragmentos recuperados ──────────────────────────────
#   [1] [Libro] EDDARD (1) | POV: EDDARD | Score: 0.4152 | Personajes: Ned, Robert Baratheon, Lyanna, Brandon, Rickard Stark, Catelyn Tully, Aerys Targaryen, Howland Reed
#   [2] [Web Scraper] Juego de Tronos-Capítulo 12 | POV: N/A | Score: 0.4081 | Personajes: N/A
#   [3] [Libro] EDDARD (1) | POV: EDDARD | Score: 0.403 | Personajes: Ned, Robert, Lyanna, Rhaegar, Jon, Catelyn, Lysa, Tywin Lannister, Benjen
#   [4] [Libro] EDDARD (9) | POV: EDDARD | Score: 0.391 | Personajes: Ned, Meñique, Heward, Jory Cassel, Wyl, Lord Baelish, Lyanna, Robert, Barra, Jon Nieve, Chataya, Lord Stannis, Lady Selyse, Renly
#   [5] [Libro] EDDARD (2) | POV: EDDARD | Score: 0.3737 | Personajes: Ned, Robert, Alyn, Ser Boros, Ser Meryn, Catelyn, Cersei, Baelor, Jorah Mormont, Lysa Arryn, Wylla
# ────────────────────────────────────────────────────────
#
# 💬 Respuesta:
# thought
# Robert y Ned hablan sobre Lyanna Stark en la **cripta de Invernalia**. En este lugar, se encuentran ante las tumbas de la Casa Stark, específicamente frente a la de Lyanna, donde Robert expresa su dolor y menciona que ella merecía algo mejor que la oscuridad.
# thought
# Robert y Ned hablan sobre Lyanna Stark en la **cripta de Invernalia**, donde se encuentran ante las tumbas de la Casa Stark. En este lugar, Robert expresa su dolor y afirma que Lyanna merecía algo mejor que la oscuridad.
# thought
# Robert y Ned hablan sobre Lyanna Stark en la **cripta de Invernalia**, donde se encuentran ante las tumbas de la Casa Stark. En este lugar, Robert expresa su dolor y afirma que Lyanna merecía algo mejor que la oscuridad.
# thought
# Robert y Ned hablan sobre Lyanna Stark en la **cripta de Invernalia**, donde se encuentran ante las tumbas de la Casa Stark. En este lugar, Robert expresa su dolor y afirma que Lyanna merecía algo mejor que la oscuridad.
# thought
# Robert y Ned hablan sobre Lyanna Stark en la **cripta de Invernalia**, donde se encuentran ante
#
# 📊 Evaluación aproximada de fidelidad
# Faithfulness score: 1.0
#
# ✅ Todas las frases parecen estar razonablemente soportadas.
#
#
# ❓ Pregunta: ¿Qué hace Viento Gris cuando el Gran Jon desafía a Robb?
#
# ── Fragmentos recuperados ──────────────────────────────
#   [1] [Web Scraper] Juego de Tronos-Capítulo 53 | POV: N/A | Score: 0.3414 | Personajes: N/A
#   [2] [Libro] BRAN (6) | POV: BRAN | Score: 0.3008 | Personajes:
#   [3] [Libro] BRAN (5) | POV: BRAN | Score: 0.1873 | Personajes:
#   [4] [Libro] CATELYN (8) | POV: CATELYN | Score: 0.1766 | Personajes:
#   [5] [Libro] BRAN (5) | POV: BRAN | Score: 0.1745 | Personajes: Bran, Robb, Hali, Osha, Stiv, Viento Gris, Verano
# ────────────────────────────────────────────────────────
